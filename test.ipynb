# %%
cost_map
# Out:
# {(1, 0): 35.88385755607755,
#  (1, 1): 35.46868889104316,
#  (1, 2): 35.068281984900686,
#  (1, 3): 34.682136843351145,
#  (1, 4): 34.30923973887605,
#  (1, 5): 33.94948145523797,
#  (1, 6): 33.601937723528806,
#  (1, 7): 33.26597420546152,
#  (1, 8): 32.9304298798867,
#  (1, 9): 32.616408048356384,
#  (1, 10): 32.31243303459671,
#  (1, 11): 32.0187791093192,
#  (1, 12): 31.734129325661293,
#  (1, 13): 31.459297426998425,
#  (1, 14): 31.193779221714394,
#  (1, 15): 30.937046119775296,
#  (1, 16): 30.688532468998744,
#  (1, 17): 30.448837397609733,
#  (1, 18): 30.21924233430192,
#  (1, 19): 29.99264109631639,
#  (1, 20): 29.776331936048063,
#  (1, 21): 29.568237733526722,
#  (1, 22): 29.36625769774417,
#  (1, 23): 29.171656300167463,
#  (1, 24): 28.98587206114618,
#  (1, 25): 28.823560300288413,
#  (1, 26): 28.644893809961843,
#  (1, 27): 28.612488349843993,
#  (1, 28): 28.455111208061567,
#  (1, 29): 28.305333754629544,
#  (1, 30): 28.1627750460292,
#  (1, 31): 28.02675297873821,
# ...

# %%
cost_map[1, 359]
# Out:
# 35.46868889104316

# %%
cost_map[1, 360] = cost_map[1, 359]
cost_map[1.4142135623730951, 360] = cost_map[1, 359]

# %%
# save the cost map as a pickle file
with open("cost_map.pkl", "wb") as f:
    pickle.dump(cost_map, f)

# %%
# make a list 0, 44, 89 ... 355
[i for i in range(0, 360, 45)]
# Out:
# [0, 45, 90, 135, 180, 225, 270, 315]
